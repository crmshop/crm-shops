# %%
from google import genai
from google.genai import types
from PIL import Image

# Usa la nuova API di Google Genai (come nel file funzionante)
client = genai.Client(api_key="AIzaSyATSPAXZAVPT3efV2ZtvbIl9WbA9Qak-9s")

# Prompt per generare un'immagine da zero
prompt = "A futuristic cityscape at golden hour with flying cars and the text 'Welcome to 2042' on a billboard, 4K resolution"

print(f"📝 Prompt: {prompt}\n")
print("🔄 Generazione immagine in corso...")

# Genera contenuto usando il modello per immagini (stesso approccio del file funzionante)
response = client.models.generate_content(
    model="gemini-2.5-flash-image",
    contents=[prompt],
)

# Processa la risposta (stesso metodo del file funzionante)
print("\n" + "=" * 60)
print("RISULTATO:")
print("=" * 60)

image_saved = False
for part in response.parts:
    if part.text is not None:
        print(f"📝 Testo: {part.text}")
    elif part.inline_data is not None:
        # Converti i dati inline in un'immagine PIL e salva (come nel file funzionante)
        generated_image = part.as_image()
        generated_image.save("output.png")
        print(f"✅ Immagine salvata come output.png")
        print(f"   Dimensione: {generated_image.size}")
        print(f"   Formato: {generated_image.format}")
        image_saved = True

if not image_saved:
    print("⚠️ Nessuna immagine trovata nella risposta")
    print(f"Parti trovate: {len(response.parts)}")
    for idx, part in enumerate(response.parts):
        print(f"  Parte {idx + 1}: {type(part)}")
        if hasattr(part, 'text') and part.text:
            print(f"    Testo: {part.text[:100]}...")
        if hasattr(part, 'inline_data'):
            print(f"    Ha inline_data: Sì")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
from SimplerLLM import ImageGenerator, ImageProvider, ImageSize

# Create generator (one-time setup)
img_gen = ImageGenerator.create(provider=ImageProvider.GOOGLE_GEMINI)

# Generate thumbnail with your face
img_gen.generate_image(
    prompt="""Professional YouTube thumbnail featuring the person from the reference image:
    - Excited, enthusiastic expression with wide eyes
    - Center-left positioning (space for text on right)
    - Dramatic professional lighting with high contrast
    - Vibrant, bold colors using warm vs cool tones
    - Dynamic gradient background, not cluttered
    - Clear even at small mobile sizes
    - Single focal point on the face
    - Optimized for maximum click-through rate""",
    reference_images=["shop.jpg"],
    size=ImageSize.HORIZONTAL,
    output_format="file",
    model="gemini-3-pro-image-preview",
    output_path="youtube_thumbnail.png"
)

print("Thumbnail generated: youtube_thumbnail.png")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# [Google Gemini API] Using model: gemini-3-pro-image-preview
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/Python_projects/CRM_shops/venv/lib/python3.13/site-packages/SimplerLLM/image/generation/providers/google_image.py:193, in generate_image(prompt, model_name, aspect_ratio, resolution, output_format, output_path, full_response, api_key, verbose, reference_images)
#     192 # Use streaming
# --> 193 for chunk in client.models.generate_content_stream(
#     194     model=model_name,
#     195     contents=contents,
#     196     config=generate_content_config,
#     197 ):
#     198     # Check if chunk has valid content
#     199     if (
#     200         chunk.candidates is None
#     201         or len(chunk.candidates) == 0
#     202         or chunk.candidates[0].content is None
# ...

# %%
from google import genai
from google.genai import types
from PIL import Image

client = genai.Client(api_key="AIzaSyATSPAXZAVPT3efV2ZtvbIl9WbA9Qak-9s")

prompt = (
    "Immagine professionale che ritrae la persona {image1} con indossati i pantaloni come da immagine {image2} mentre cammina con scarpe {image3}, vista di tre quarti, in mezzo ad altra gente. Il volto deve essere fedele alla foto così come la forma fisica.",
)

image = Image.open("shop2.jpg")
image2 = Image.open("panta.jpg")
image3 = Image.open("scarpe.jpg")

response = client.models.generate_content(
    model="gemini-2.5-flash-image",
    contents=[prompt, image, image2, image3],
)

for part in response.parts:
    if part.text is not None:
        print(part.text)
    elif part.inline_data is not None:
        image = part.as_image()
        image.save("generated_image.png")
# Out:
# Certo, ecco un'immagine professionale dell'uomo nella tua foto, con i pantaloni e le scarpe specificati, mentre cammina tra la gente, vista di tre quarti:
